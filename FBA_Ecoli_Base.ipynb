# %%
import cobra
import pandas as pd
import numpy as np
from cobra.io import load_model
from cobra.flux_analysis import flux_variability_analysis

# %%
# Import Cobra along with the load model module that allows us to use thier example 
    # models 
# The output here 

import cobra
from cobra.io import load_model 
model = load_model("textbook")
print(model)
# Out:
# e_coli_core

# %%
# Run the Flux balance analysis on the model of Ecoli
# I beleive the objective here is just the maximium growth rate as a default 
# The summary will print out all of the main reactions that involve matabilites
    # uptaken by the cell. For example the matabolite_e corrosponds to an
    # extracellular motabolite. Similarly, the corresponding intracellular motabolite
    # can be represented by glc__D_c
# The flux corrosponds to the amount of matabolite consumed hence -ve flux indicates
    # that there is production

solution = model.optimize()
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass_Ecoli_core = 0.8739215069684312</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
# ...

# %%
# The "model.matabolites" function can be used to identify which reactions are
    # involved in a matabolite 

model.metabolites.glc__D_e.summary()
# Out:
# <h3>glc__D_e</h3><p>C6H12O6</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>10</td>
#       <td>EX_glc__D_e</td>
#       <td>glc__D_e &lt;=&gt;</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-10</td>
#       <td>GLCpts</td>
#       <td>glc__D_e + pep_c --&gt; g6p_c + pyr_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Flux through glycolysis 
    # Need to create a summary of the flux through all the reactions '
    # Can I get a dataframe that represents
flux_variability_analysis(model, model.reactions[:29])
# Out:
#                          minimum       maximum
# ACALD               8.656583e-14  0.000000e+00
# ACALDt              8.656583e-14  0.000000e+00
# ACKr                1.617709e-13  3.192215e-14
# ACONTa              6.007250e+00  6.007250e+00
# ACONTb              6.007250e+00  6.007250e+00
# ACt2r               1.617709e-13  3.192215e-14
# ADK1                0.000000e+00 -5.843193e-13
# AKGDH               5.064376e+00  5.064376e+00
# AKGt2r              4.869328e-14  0.000000e+00
# ALCD2x              7.539604e-14  0.000000e+00
# ATPM                8.390000e+00  8.390000e+00
# ATPS4r              4.551401e+01  4.551401e+01
# Biomass_Ecoli_core  8.739215e-01  8.739215e-01
# CO2t               -2.280983e+01 -2.280983e+01
# CS                  6.007250e+00  6.007250e+00
# CYTBD               4.359899e+01  4.359899e+01
# D_LACt2             7.303992e-14  0.000000e+00
# ENO                 1.471614e+01  1.471614e+01
# ETOHt2r             7.539604e-14  0.000000e+00
# ...

# %%
# Reactions present in glycolosis (indentations represent side reactions )
    # 1. EX_glc__D_e representing gluecose uptake [28]
    # 2. GLCpts representing gluecose into g6p [50]
         # 3. G6PDH2r representing g6p into 6pgl_c
    # 4. PGI representing g6p into f6p 
    # 5. PFK
    # 6.
    # 7.
    # 8.
    #

       
flux_variability_analysis(model, model.reactions)
# Out:
#              minimum       maximum
# ACALD   8.656583e-14  0.000000e+00
# ACALDt  8.656583e-14  0.000000e+00
# ACKr    1.617709e-13  3.192215e-14
# ACONTa  6.007250e+00  6.007250e+00
# ACONTb  6.007250e+00  6.007250e+00
# ...              ...           ...
# TALA    1.496984e+00  1.496984e+00
# THD2    0.000000e+00 -1.845898e-12
# TKT1    1.496984e+00  1.496984e+00
# TKT2    1.181498e+00  1.181498e+00
# TPI     7.477382e+00  7.477382e+00
#
# [95 rows x 2 columns]

# %%
model.reactions
# Out:
# [<Reaction ACALD at 0x12979a6a0>,
#  <Reaction ACALDt at 0x1297a5e50>,
#  <Reaction ACKr at 0x1297b39a0>,
#  <Reaction ACONTa at 0x1297b3820>,
#  <Reaction ACONTb at 0x1297b3d90>,
#  <Reaction ACt2r at 0x1297bb5e0>,
#  <Reaction ADK1 at 0x1297b3e50>,
#  <Reaction AKGDH at 0x1297b3790>,
#  <Reaction AKGt2r at 0x1297bbf40>,
#  <Reaction ALCD2x at 0x1297bbf70>,
#  <Reaction ATPM at 0x1297bbe80>,
#  <Reaction ATPS4r at 0x1297b37c0>,
#  <Reaction Biomass_Ecoli_core at 0x1297b3310>,
#  <Reaction CO2t at 0x1297b3370>,
#  <Reaction CS at 0x1297bbc40>,
#  <Reaction CYTBD at 0x1297c7c10>,
#  <Reaction D_LACt2 at 0x128476ca0>,
#  <Reaction ENO at 0x128106b80>,
#  <Reaction ETOHt2r at 0x1296b8520>,
#  <Reaction EX_ac_e at 0x1296b8880>,
#  <Reaction EX_acald_e at 0x1297c7b80>,
#  <Reaction EX_akg_e at 0x1296cda90>,
#  <Reaction EX_co2_e at 0x1297c2e50>,
#  <Reaction EX_etoh_e at 0x1296b8d60>,
#  <Reaction EX_for_e at 0x129444df0>,
#  <Reaction EX_fru_e at 0x1297c2e80>,
# ...
